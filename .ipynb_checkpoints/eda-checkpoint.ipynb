# %% [markdown]
# # Warning: this is purely playing around. These are based on mishandled data

# %%
import import_ipynb
from data_cleaning import *
import matplotlib.pyplot as plt
import numpy as np
# Out:
# importing Jupyter notebook from data_cleaning.ipynb
# Gathering player lookup table. This may take a moment.
# Number of players we searched: 383
# Number of result that we got: 368
# (13069, 320)

# %%
salaryFinalDF.head()
# Out:
#               name position   age from_team to_team  avg_salary  year_fa  \
# 0       A.J. Ellis        C  35.6       PHI     MIA   2500000.0     2017
# 1  A.J. Pierzynski        C  37.5       BOS     STL    500000.0     2014
# 2  A.J. Pierzynski        C  35.9       CHW     TEX   7500000.0     2013
# 3  A.J. Pierzynski        C  37.9       STL     ATL   2000000.0     2015
# 4  A.J. Pierzynski        C  38.8       ATL     ATL   3000000.0     2016
#
#    IDfg  first_played  last_played
# 0  5677        2008.0       2018.0
# 1   746        1998.0       2016.0
# 2   746        1998.0       2016.0
# 3   746        1998.0       2016.0
# 4   746        1998.0       2016.0

# %%
# distribution of avg_salary info
plt.hist(salaryFinalDF['avg_salary'], log=True, color='plum', edgecolor='black')
# Out:
# (array([302., 104.,  54.,  40.,  24.,  16.,   6.,  13.,   0.,   2.]),
#  array([   49914. ,  3294922.6,  6539931.2,  9784939.8, 13029948.4,
#         16274957. , 19519965.6, 22764974.2, 26009982.8, 29254991.4,
#         32500000. ]),
#  <BarContainer object of 10 artists>)

# %%
salaryFinalDF.insert(len(salaryFinalDF.columns), 'avg_salary_log',
         np.log(salaryFinalDF['avg_salary']))
salaryFinalDF.head()
# Out:
#               name position   age from_team to_team  avg_salary  year_fa  \
# 0       A.J. Ellis        C  35.6       PHI     MIA   2500000.0     2017
# 1  A.J. Pierzynski        C  37.5       BOS     STL    500000.0     2014
# 2  A.J. Pierzynski        C  35.9       CHW     TEX   7500000.0     2013
# 3  A.J. Pierzynski        C  37.9       STL     ATL   2000000.0     2015
# 4  A.J. Pierzynski        C  38.8       ATL     ATL   3000000.0     2016
#
#    IDfg  first_played  last_played  avg_salary_log
# 0  5677        2008.0       2018.0       14.731801
# 1   746        1998.0       2016.0       13.122363
# 2   746        1998.0       2016.0       15.830414
# 3   746        1998.0       2016.0       14.508658
# 4   746        1998.0       2016.0       14.914123

# %%
# distribution of avg_salary_log
plt.hist(salaryFinalDF['avg_salary_log'], range=(10, 18), bins=8, color='mediumseagreen', edgecolor='black')
# Out:
# (array([  1.,   0.,   2., 130., 169., 151., 102.,   6.]),
#  array([10., 11., 12., 13., 14., 15., 16., 17., 18.]),
#  <BarContainer object of 8 artists>)

# %%
# plot scatter plot of salary vs. age

plt.scatter(salaryFinalDF['age'], salaryFinalDF['avg_salary_log'], c='lightblue', alpha=0.5)
plt.show()

# %%
# scatterplot: salary vs. position
plt.scatter(salaryFinalDF['position'], salaryFinalDF['avg_salary_log'], c='lightblue', alpha=0.5)
plt.show()

# %%
# box plot: salary vs. position

data_1 = salaryFinalDF[salaryFinalDF['position'] == 'C']['avg_salary_log']
data_2 = salaryFinalDF[salaryFinalDF['position'] == '1B']['avg_salary_log']
data_3 = salaryFinalDF[salaryFinalDF['position'] == '2B']['avg_salary_log']
data_4 = salaryFinalDF[salaryFinalDF['position'] == 'SS']['avg_salary_log']
data_5 = salaryFinalDF[salaryFinalDF['position'] == '3B']['avg_salary_log']
data_6 = salaryFinalDF[salaryFinalDF['position'] == 'OF']['avg_salary_log']
data_7 = salaryFinalDF[salaryFinalDF['position'] == 'DH']['avg_salary_log']
data = [data_1, data_2, data_3, data_4, data_5, data_6, data_7]

fig = plt.figure(figsize =(9, 4))
ax = fig.add_axes([0, 0, 1, 1])

ax.set_xlabel('Position')
ax.set_ylabel('Avg. Salary Log')

bp = ax.boxplot(data, labels=["C", "1B", "2B", "SS", "3B", "OF", "DH"])
plt.show()

# %%
batting_aggDF
# Out:
#                            Age    G    PA    AB    R    H   2B  3B   HR  RBI  \
# IDfg  Name
# 5677  A.J. Ellis            35  468  1713  1448  143  341   63   2   35  172
# 746   A.J. Pierzynski       36  664  2587  2424  254  682  122   7   74  300
#       A.J. Pierzynski       35  664  2628  2455  272  695  129   7   70  290
#       A.J. Pierzynski       37  628  2414  2258  222  616  112   7   66  288
#       A.J. Pierzynski       38  613  2347  2191  217  610  107   8   66  281
# ...                        ...  ...   ...   ...  ...  ...  ...  ..  ...  ...
# 11368 Yasmani Grandal       29  638  2326  2000  254  471   95   4  104  294
#       Yasmani Grandal       30  663  2515  2136  286  512  102   5  117  322
# 2530  Yonder Alonso         30  582  2118  1888  235  500  104   2   53  226
# 8585  Yuniesky Betancourt   30  647  2498  2356  238  604  126  15   49  282
# 2616  Zack Cozart           31  594  2390  2169  297  553  110  18   65  242
#
#                            SB  CS   BB   SO  GDP  HBP  SH  SF  IBB     AVG  \
# IDfg  Name
# 5677  A.J. Ellis            2   3  214  311   52   17  19  15   20  0.2306
# 746   A.J. Pierzynski       5   6  101  278   76   29  12  21   21  0.2814
#       A.J. Pierzynski       5   5  109  273   76   28  15  21   24  0.2832
#       A.J. Pierzynski       4   6   91  280   71   33  10  22   17  0.2716
#       A.J. Pierzynski       1   4   95  278   73   34   4  23   17  0.2776
# ...                        ..  ..  ...  ...  ...  ...  ..  ..  ...     ...
# 11368 Yasmani Grandal       6   6  299  577   56    9   2  16    4  0.2350
#       Yasmani Grandal       8   7  350  601   65   12   2  15    5  0.2392
# 2530  Yonder Alonso        19   7  204  323   54    9   0  17   16  0.2644
# 8585  Yuniesky Betancourt  13  15   86  238   79    5  22  29    4  0.2526
# 2616  Zack Cozart          17   4  164  372   49   16  20  21    9  0.2564
#
#                               OBP     SLG   BABIP     ISO     OPS  wRC  \
# IDfg  Name
# 5677  A.J. Ellis           0.3340  0.3466  0.2680  0.1164  0.6804  183
# 746   A.J. Pierzynski      0.3154  0.4288  0.2898  0.1476  0.7440  301
#       A.J. Pierzynski      0.3184  0.4270  0.2922  0.1440  0.7452  305
#       A.J. Pierzynski      0.3068  0.4112  0.2840  0.1398  0.7180  268
#       A.J. Pierzynski      0.3146  0.4196  0.2904  0.1422  0.7342  274
# ...                           ...     ...     ...     ...     ...  ...
# 11368 Yasmani Grandal      0.3352  0.4412  0.2742  0.2060  0.7764  309
#       Yasmani Grandal      0.3458  0.4546  0.2746  0.2154  0.8004  359
# 2530  Yonder Alonso        0.3336  0.4028  0.2912  0.1384  0.7366  255
# 8585  Yuniesky Betancourt  0.2778  0.3858  0.2594  0.1332  0.6632  224
# 2616  Zack Cozart          0.3110  0.4226  0.2768  0.1660  0.7334  267
#
#                                    wRAA  wRC+   WPA   WAR  Year_FA  \
# IDfg  Name
# 5677  A.J. Ellis          -8.400000e+00   464 -1.46   2.6     2017
# 746   A.J. Pierzynski      6.000000e+00   473 -2.58   8.8     2014
#       A.J. Pierzynski     -1.665335e-16   468 -2.85   9.7     2013
#       A.J. Pierzynski     -2.400000e+00   452 -4.54   5.3     2015
#       A.J. Pierzynski      1.210000e+01   483 -2.46   5.1     2016
# ...                                 ...   ...   ...   ...      ...
# 11368 Yasmani Grandal      4.150000e+01   574 -1.00  22.3     2019
#       Yasmani Grandal      5.890000e+01   585  1.48  25.0     2020
# 2530  Yonder Alonso        1.230000e+01   523  3.64   4.4     2018
# 8585  Yuniesky Betancourt -6.740000e+01   374 -7.71  -2.8     2013
# 2616  Zack Cozart         -4.900000e+00   469 -3.56  11.0     2018
#
#                                Salary  Salary_log
# IDfg  Name
# 5677  A.J. Ellis            2500000.0   14.731801
# 746   A.J. Pierzynski        500000.0   13.122363
#       A.J. Pierzynski       7500000.0   15.830414
#       A.J. Pierzynski       2000000.0   14.508658
#       A.J. Pierzynski       3000000.0   14.914123
# ...                               ...         ...
# 11368 Yasmani Grandal      18250000.0   16.719676
#       Yasmani Grandal      18250000.0   16.719676
# 2530  Yonder Alonso         8000000.0   15.894952
# 8585  Yuniesky Betancourt    900000.0   13.710150
# 2616  Zack Cozart          12666667.0   16.354484
#
# [561 rows x 33 columns]

# %%
plt.scatter(batting_aggDF['Year_FA'], batting_aggDF['Salary_log'], c='lightblue', alpha=0.7)
plt.show()
